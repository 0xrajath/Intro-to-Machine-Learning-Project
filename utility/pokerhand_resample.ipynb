# %%
import pandas as pd
import matplotlib as plt

# %%
# Python function to print permutations of a given list 
def permutation(lst): 
  
    # If lst is empty then there are no permutations 
    if len(lst) == 0: 
        return [] 
  
    # If there is only one element in lst then, only 
    # one permuatation is possible 
    if len(lst) == 1: 
        return [lst] 
  
    # Find the permutations for lst if there are 
    # more than 1 characters 
  
    l = [] # empty list that will store current permutation 
  
    # Iterate the input(lst) and calculate the permutation 
    for i in range(len(lst)): 
       m = lst[i] 
  
       # Extract lst[i] or m from the list.  remLst is 
       # remaining list 
       remLst = lst[:i] + lst[i+1:] 
  
       # Generating all permutations where m is first 
       # element 
       for p in permutation(remLst): 
           l.append([m] + p) 
    return l

# %%
# Permute a given hand

def permute_hand(df,hand):
    temp=[]

    for row in df.iterrows():
        index, data = row
        temp.append(data.tolist())

    tuple_list = []

    for rowList in temp:
        tuple_list.append([(rowList[0],rowList[1]),(rowList[2],rowList[3]),(rowList[4],rowList[5]),(rowList[6],rowList[7]),(rowList[8],rowList[9])])

    #print(len(tuple_list))
    final_list = []

    for rowList in tuple_list:
        perm_list = permutation(rowList)
        for perm in perm_list:
            final_list_row = []
            final_list_row.append(perm[0][0])
            final_list_row.append(perm[0][1])
            final_list_row.append(perm[1][0])
            final_list_row.append(perm[1][1])
            final_list_row.append(perm[2][0])
            final_list_row.append(perm[2][1])
            final_list_row.append(perm[3][0])
            final_list_row.append(perm[3][1])
            final_list_row.append(perm[4][0])
            final_list_row.append(perm[4][1])
            final_list_row.append(hand)
            final_list.append(final_list_row)


    return final_list

# %%
# Going to permute existing dataset
df_train_check = pd.read_csv('data/poker_hand_train.csv')
df_train_check
# Out:
#        S1  C1  S2  C2  S3  C3  S4  C4  S5  C5  hand
# 0       4   9   2   1   2   2   4   7   2   8     0
# 1       1   4   3   6   1  12   3  11   2   7     0
# 2       1  11   4   1   3   7   4  11   2   1     2
# 3       2   9   2   4   3   6   1   9   4   9     3
# 4       1   8   2   4   2  11   2   2   2   1     0
# 5       2   5   1   5   2  13   2   3   3  13     2
# 6       3  10   4   6   1   4   2  13   4   5     0
# 7       4  10   3   1   2  13   4   2   4   7     0
# 8       3   2   4  10   3   3   4   4   1   9     0
# 9       2   7   3   8   4   8   2  13   2  12     1
# 10      2   5   1   3   2  10   3   2   2   1     0
# 11      1   6   2  12   4   7   2  10   1   1     0
# 12      4   2   4   9   1  12   3   7   2  11     0
# 13      2   6   1   5   3   3   4   2   4   5     1
# 14      1   6   3  12   4  11   2  11   3  13     1
# 15      2   5   2   4   4   9   2   3   3   2     0
# 16      4   9   4  11   3   8   3   9   3   5     1
# ...

# %%
df_perm_final = pd.DataFrame(columns=["S1","C1","S2","C2","S3","C3","S4","C4","S5","C5","hand"])

for i in range(10):
    df_hand = df_train_check[df_train_check.hand == i]
    df_hand = df_hand.reset_index(drop=True)
    
    # New Three of a Kind Dataframe
    hand_perm = permute_hand(df_hand,i)

    df_hand_permute =pd.DataFrame(hand_perm,columns=["S1","C1","S2","C2","S3","C3","S4","C4","S5","C5","hand"])
    df_perm_final = df_perm_final.append(df_hand_permute)
    print(i," Done")

    
df_perm_final.drop_duplicates(keep=False, inplace=True)
df_perm_final = df_perm_final.sample(frac=1).reset_index(drop=True)
df_perm_final
# Out:
# 0  Done
# 1  Done
# 2  Done
# 3  Done
# 4  Done
# 5  Done
# 6  Done
# 7  Done
# 8  Done
# 9  Done
#         S1  C1 S2  C2 S3  C3 S4  C4 S5  C5 hand
# 0        2   5  3  10  3   3  2   7  4  11    0
# 1        3  11  1   3  3   4  1   7  4   9    0
# 2        1   9  2  11  4  12  1   6  2   5    0
# 3        1  13  4   1  4   4  4   7  1   5    0
# 4        3   8  1   3  4  11  1   1  2   5    0
# 5        2   5  3   4  3   7  2   1  1   3    0
# 6        4  10  4   9  4  12  4   1  4  13    5
# 7        3   5  1  13  4   2  4   7  2   3    0
# 8        1   5  2   3  3   1  2   6  2  13    0
# 9        2   6  4  10  3  12  3  11  1   8    0
# 10       3  11  2   2  3   8  1  10  4   4    0
# 11       3   5  2  11  2   5  2   9  2  13    1
# 12       2   9  4   3  1  10  4   6  4   2    0
# 13       4  12  4  11  3   8  3  11  3   4    1
# 14       4   5  3   2  3   9  4   6  2   3    0
# 15       3  12  4  11  2   9  1   2  1  13    0
# 16       4   4  4   6  4   7  1   9  1  12    0
# ...

# %%
df_perm_final['hand'].plot(kind='hist')

# %%
df_perm_final_new = df_perm_final.sample(frac=0.6).reset_index(drop=True)
df_perm_final_new
# Out:
#         S1  C1 S2  C2 S3  C3 S4  C4 S5  C5 hand
# 0        3  13  2   3  4  12  3   5  3   7    0
# 1        2  10  3   9  4  12  4   8  4  11    4
# 2        2   9  4   1  3  11  1   9  3  13    1
# 3        4   9  4  10  3   1  4   4  1   1    1
# 4        2   5  4   2  2  10  2   6  3  11    0
# 5        3   3  3  10  2  13  4  13  4   4    1
# 6        1   4  3   7  3   9  4  11  4   8    0
# 7        3   2  4   7  4   4  1   3  4   5    0
# 8        1   1  2   3  3   4  4   3  3   9    1
# 9        3  12  3  11  2   3  4   5  4   4    0
# 10       4   7  3   8  3  13  2   9  2   1    0
# 11       3   5  4  10  1   3  3   9  4   8    0
# 12       2   6  2   7  4   8  3   8  3  13    1
# 13       2   3  2   9  1  10  4   8  1  12    0
# 14       3  11  1   4  3   5  4   7  2   1    0
# 15       2   6  1   2  4   4  4  13  1  13    1
# 16       2   1  4   8  3   4  3   3  2  10    0
# 17       2   4  2   1  3   5  3  10  3   1    1
# 18       1  11  3   2  4  11  4   5  2   8    1
# ...

# %%
df_perm_final_new['hand'].plot(kind='hist')

# %%
df_perm_final_new.to_csv('data/poker_hand_train_resample4.csv', encoding='utf-8', index=False)
